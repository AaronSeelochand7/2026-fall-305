# %% [markdown]
# <a href="https://colab.research.google.com/github/AaronSeelochand7/2026-fall-305/blob/main/cost_behavior.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Cost Behavior Analysis
# ## Cost Accounting Riverben Manufacturing
#
# We have 24 months of production and cost data
# Our job is to work out how each cost behaves when the number of units produced changes.
#
# Cost driver (activity base): Units_Produced
#
# https://github.com/AaronSeelochand7/2026-Fall-305

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/cost_behavior_data.csv")
# print("Row and Column:", df.shape)
# print("R and c:", df.shape)
# dispaly(df.head()), tail, sample, iloc[]
# display(df.info())
# display(df.describe())

# %%
df = pd.read_csv("https://raw.githubusercontent.com/qcprof/2026-fall-305/main/cost_behavior_data.csv")
# print("Row and Column:", df.shape)
# print("R and c:", df.shape)
# dispaly(df.head()), tail, sample, iloc[]
# display(df.info())
# display(df.describe())
